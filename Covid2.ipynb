# %% [markdown]
# <a href="https://colab.research.google.com/github/musinaa/elijahmusina.github.io/blob/change-the-layout/Covid2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("national_data.csv")
df
# Out:
#                    data  deceased  discharged  isolation  positive_cases  \
# 0   2020-02-24T18:00:00         7           1         94             221
# 1   2020-02-25T18:00:00        10           1        162              93
# 2   2020-02-26T18:00:00        12           3        221              78
# 3   2020-02-27T18:00:00        17          45        284             250
# 4   2020-02-28T18:00:00        21          46        412             238
# 5   2020-02-29T18:00:00        29          50        543             240
# 6   2020-03-01T18:00:00        34          83        798             566
# 7   2020-03-02T18:00:00        52         149        927             342
# 8   2020-03-03T18:00:00        79         160       1000             466
# 9   2020-03-04T18:00:00       107         276       1065             587
# 10  2020-03-05T18:00:00       148         414       1155             769
# 11  2020-03-06T18:00:00       197         523       1060             778
# ...

# %%
df.head()
# Out:
#                   data  deceased  discharged  isolation  positive_cases  \
# 0  2020-02-24T18:00:00         7           1         94             221
# 1  2020-02-25T18:00:00        10           1        162              93
# 2  2020-02-26T18:00:00        12           3        221              78
# 3  2020-02-27T18:00:00        17          45        284             250
# 4  2020-02-28T18:00:00        21          46        412             238
#
#    recovered state  tests  total cases
# 0        101   ITA   4324          229
# 1        114   ITA   8623          322
# 2        128   ITA   9587          400
# 3        248   ITA  12014          650
# 4        345   ITA  15695          888

# %%
df.columns
# Out:
# Index(['data', 'deceased', 'discharged', 'isolation', 'positive_cases',
#        'recovered', 'state', 'tests', 'total cases'],
#       dtype='object')

# %%
df.tail()
# Out:
#                    data  deceased  discharged  isolation  positive_cases  \
# 32  2020-03-27T17:00:00      9134       10950      36653            5959
# 33  2020-03-28T17:00:00     10023       12384      39533            5974
# 34  2020-03-29T17:00:00     10779       13030      42588            5217
# 35  2020-03-30T17:00:00     11591       14620      43752            4050
# 36  2020-03-31T17:00:00     12428       15729      45420            4053
#
#     recovered state   tests  total cases
# 32      26029   ITA  394079        86498
# 33      26676   ITA  429526        92472
# 34      27386   ITA  454030        97689
# 35      27795   ITA  477359       101739
# 36      28192   ITA  506968       105792

# %%
df.describe()
# Out:
#            deceased    discharged     isolation  positive_cases     recovered  \
# count     37.000000     37.000000     37.000000       37.000000     37.000000
# mean    3153.027027   3981.270270  13257.162162     2859.027027  10729.135135
# std     3865.486267   4769.178305  14985.718951     2219.396320   9977.361968
# min        7.000000      1.000000     94.000000       78.000000    101.000000
# 25%      107.000000    276.000000   1060.000000      587.000000   1346.000000
# 50%     1266.000000   1439.000000   6201.000000     2651.000000   7426.000000
# 75%     5476.000000   7024.000000  23783.000000     5210.000000  19846.000000
# max    12428.000000  15729.000000  45420.000000     6557.000000  28192.000000
#
#                tests    total cases
# count      37.000000      37.000000
# mean   156444.432432   32792.945946
# std    154319.976861   34812.643662
# min      4324.000000     229.000000
# 25%     29837.000000    3089.000000
# 50%     97488.000000   17660.000000
# ...

# %%
df.isnull().sum()
# Out:
# data              0
# deceased          0
# discharged        0
# isolation         0
# positive_cases    0
# recovered         0
# state             0
# tests             0
# total cases       0
# dtype: int64

# %%
sns.relplot(x="total cases", y="recovered", data=df)

# %%
sns.relplot(x="total cases", y="deceased", data=df)

# %%
sns.relplot(x="total cases", y="positive_cases", data=df)

# %%
sns.pairplot(df)

# %%
sns.relplot(x='total cases', y='isolation', kind='line', data=df)
